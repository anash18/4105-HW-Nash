# %% [markdown]
# <a href="https://colab.research.google.com/github/anash18/4105-HW-Nash/blob/main/4105_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem 1

#Importing Python Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

#Importing File from MyDrive
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/4105 Datasets/D3.csv'
sample = pd.DataFrame(pd.read_csv(file_path))
sample.head()

x1 = sample.values[:, 0]
x2 = sample.values[:, 1]
x3 = sample.values[:, 2]
y1 = sample.values[:, 3]
m = len(y1)  # Number of training examples
n = len(x1)  # Number of training examples

# Display first 5 records and the total number of training examples
#print('X1 = ', x1[: 5])
#print('X2 = ', x2[: 5])
#print('X3 = ', x3[: 5])
#print('Y1 = ', y1[: 5])
#print('m = ', m)
#print('n = ', n)

from IPython.display import display
#display(sample)

#scatter plot
plt.scatter(x1,y1, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.title('Scatter plot of training data')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.scatter(x2,y1, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.title('Scatter plot of training data')

# Show the plot
plt.show()

# %%
plt.scatter(x3,y1, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.title('Scatter plot of training data')

# Show the plot
plt.show()

# %%
#Steps towards linear regression
X_0 = np.ones((m, 1))
X_1 = x1.reshape(m, 1)
X_2 = x2.reshape(m, 1)
X_3 = x3.reshape(m, 1)

X1 = np.hstack((X_0,X_1))
X2 = np.hstack((X_0,X_2))
X3 = np.hstack((X_0,X_3))

#checking that the arrays reshaped correctly
#print(X1[:5])
#print(X2[:5])
#print(X3[:5])

#setting up theta array
theta = np.zeros(2)
theta

#defining compute cost function
def compute_cost(X, y, theta):
  predictions = X.dot(theta)
  errors = np.subtract(predictions, y)
  sqrErrors = np.square(errors)
  J = 1 / (2 * m) * np.sum(sqrErrors)
  return J

# Lets compute the cost for theta values
cost = compute_cost(X1, y1, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)

#defining gradient descent
def gradient_descent(X, y, theta, alpha, iterations):
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history
iterations = 1500
alpha = 0.1
theta, cost_history = gradient_descent(X1, y1, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242
# Final value of theta = [ 5.92794892 -2.03833663]
# cost_history = [5.16999006 4.96338989 4.7855721  ... 0.98499308 0.98499308 0.98499308]

# %%
# Scatter plot for the training data
plt.scatter(X1[:, 1], y1, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X1[:, 1], X1.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
#X2

#Setting Up Variables
iterations = 1500
alpha = 0.1
theta = [0.,0.]


# Lets compute the cost for theta values
cost_2 = compute_cost(X2, y1, theta)
#print('The cost for given values of theta_0 and theta_1 =', cost_2)


theta, cost_history = gradient_descent(X2, y1, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)

# Scatter plot for the training data
plt.scatter(X2[:, 1], y1, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X2[:, 1], X2.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

#Gradient Descent Graph
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()
# Out:
# Final value of theta = [0.73606043 0.55760761]
# cost_history = [3.90731819 3.66528504 3.62832072 ... 3.59936602 3.59936602 3.59936602]

# %%
#X3

#Setting Up Variables
iterations = 1500
alpha = 0.1
theta = [0.,0.]


# Lets compute the cost for theta values
cost_2 = compute_cost(X3, y1, theta)
#print('The cost for given values of theta_0 and theta_1 =', cost_2)


theta, cost_history = gradient_descent(X3, y1, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)

# Scatter plot for the training data
plt.scatter(X3[:, 1], y1, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X3[:, 1], X3.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

#Gradient Descent Graph
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()
# Out:
# Final value of theta = [ 2.8714221  -0.52048288]
# cost_history = [4.66843939 4.49602325 4.43685075 ... 3.62945112 3.62945112 3.62945112]

# %%
#Problem 2
#Steps towards linear regression
X_0 = np.ones((m, 1))
X_1 = x1.reshape(m, 1)
X_2 = x2.reshape(m, 1)
X_3 = x3.reshape(m, 1)

#using the hstack() function to stack X_0, X_1, X_2, and X_3 horizontally
X_final = np.hstack((X_0, X_1,X_2,X_3))
#X[:5]

#Setting Up Variables
iterations = 1500
alpha = 0.1
theta = [0.,0.,0.,0.]


# Lets compute the cost for theta values
cost_all = compute_cost(X_final, y1, theta)
#print('The cost for given values of theta_0 and theta_1 =', cost_2)


theta, cost_history = gradient_descent(X_final, y1, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)


#Gradient Descent Graph
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()
# Out:
# Final value of theta = [ 5.31416563 -2.00371905  0.53256359 -0.26560164]
# cost_history = [4.13064348 3.51770697 3.12758306 ... 0.73846424 0.73846424 0.73846424]

# %%
# Predicting the value of y at certain points

#setting up x0 = 1
x_0 = 1;

#setting up new array 1
new_array_1 = np.array([x_0,1,1,1]);

#finding the dot product of the new array 1 and the theta value
y_1 = new_array_1.dot(theta);

print('The predicted value for y_1 at the specified point is =', y_1)

#setting up new array 2
new_array_2 = np.array([x_0,2,0,4])

#finding the dot product of the new array 2 and the theta value
y_2 = new_array_2.dot(theta);

print('The predicted value for y_2 at the specified point is =', y_2)

#setting up new array 3
new_array_3 = np.array([x_0,3,2,1]);

#finding the dot product of the new array 3 and the theta value
y_3 = new_array_3.dot(theta);

print('The predicted value for y_3 at the specified point is=', y_3)
# Out:
# The predicted value for y_1 at the specified point is = 3.577408529345462
# The predicted value for y_2 at the specified point is = 0.2443209702176523
# The predicted value for y_3 at the specified point is= 0.1025340197359193
